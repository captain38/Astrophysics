# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
M=np.arange(0.1,10,.1)

Tc=6.67e-11/1.38e-23*M**.3/4*1.989e30/5.957e9*1.67e-27
Pc=15/32/np.pi*6.67/10**11/M**.8*1.989e30**2/5.957e9**4

# %%
plt.plot(M,Tc)
plt.title("Central Temp (K) vs. Mass kg")
# Out:
# Text(0.5,1,'Central Temp (K) vs. Mass kg')

# %%
plt.plot(M,Pc)
plt.title("Central Pressure vs. Mass (solar masses)")
# Out:
# Text(0.5,1,'Central Pressure vs. Mass (solar masses)')
